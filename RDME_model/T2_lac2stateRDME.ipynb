# %% [markdown]
# # Tutorial 2 - The *lac* System with Spatial Resolution
#
# This is like tutorial in CME tutorial  `lac2stateCME.ipynb`, except we investigate the system with spatial resolution.
#
# The model presented here can be found in the article: [Noise Contributions in an Inducible Genetic Switch: A Whole-Cell Simulation Study](http://journals.plos.org/ploscompbiol/article?id=10.1371/journal.pcbi.1002010).

# %%
import os
import jLM                                  # Set up the Jupyter environment
from jLM.RDME import Sim as RDMESim         # Main simulation class
from jLM.RegionBuilder import RegionBuilder # Deal with the spatial geometry
from lm import IntMpdRdmeSolver             # lm::rdme::IntMpdRdmeSolver
import pyLM.units as unitsconv             # Unit converters
import numpy as np
# %matplotlib inline
# Out:
# <style>
# table.fullWidth {
#     width: 100%;
# }
#
# table.jLMtbl {
#     border: 1px solid #000;
# }
#
# .jLMtbl td, .jLMtbl tr, .jLMtbl th, .diffTbl table, .diffTbl td, .diffTbl tr {
#     border: 0px;
# }
#
# .jLMtbl caption, .diffTbl caption {
#     font-size: 1.5em;
#     font-weight: bold;
#     color: #555;
#     text-align: left;
#     padding: 15px 10px 8px 10px;
# }
#
# .jLMtbl td, .jLMtbl th {
#     padding-left: 10px;
#     padding-right: 10px;
# }
#
# .jLMtbl tr:nth-child(even) { background: #ddd;  }
# .jLMtbl tr:nth-child(odd) { background: #f8f8f8;  }
#
# table.diffTbl {
#     border: 0px;
# }
#
# td.noWrap {
#     white-space:nowrap;
# }
#
# .diffTbl span.rot {
#     -webkit-transform: rotate(-90deg);
#     transform: rotate(-90deg);
#     display: inline-block;
#     white-space: nowrap;
# }
#
# .diffTbl td[rowspan], .diffTbl td[colspan] {
#     background: #fff;
#     font-weight: bold;
# }
#
# .diffTbl td[rowspan] {
#     width: 0.01em;
#     padding: 0em 0.2em;
# }
#
# .diffTbl td {
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     vertical-align: middle;
#     background-color: hsla(0,0%,90%,1);
#     color: #000;
# }
#
#
# .diffTbl td.rhdr {
#     text-align: right;
#     background: #555;
#     color: #fff;
# }
#
# .diffTbl td.units {
#     background: #fff;
#     color: #000;
# }
#
# .diffTbl td.chdr {
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     background: #555;
#     color: #fff;
# }
#
# .diffTbl td.zero {
#     background-color: hsla(180,100%,90%,1);
# }
#
# .diffTbl td.inf {
#     background-color: hsla(0,100%,90%,1);
# }
#
# .diffTbl td.undef {
#     background-color: #f00;
#     color: #fff;
# }
#
#
# .jLMtbl th {
#     border: 0px;
#     background: #555;
#     color: #fff;
# }
#
# .jLMtbl th[scope=col] {
#     height: 40px;
#     text-align: center;
#     vertical-align: middle;
# }
#
# .jLMtbl th[scope=row] {
#     text-align: left;
# }
#
# td.jLMparam{
#     width: 250px;
#     text-align: right;
#     padding-right: 15px;
# }
#
#
# td.rxnCol {
#     text-align: center;
#     width: 333px;
# }
#
# td.objIndex {
#     width: 15px;
#     text-align:center;
#     vertical-align:middle;
# }
#
#
# div.jLMflex {
#     width: 100%;
#     display: flex;
#     margin:0;
# }
#
# div.regRight, div.trajRight {
#     flex-grow: 1;
# }
#
# div.trajRight {
#     padding-top: 20px;
# }
#
# div.regLeft {
#     width:200px;
# }
#
# div.trajLeft {
#     width:400px;
# }
#
# div.jLMx3Dkey {
#     display: block;
#     position: absolute;
#     background-color: rgba(255,255,255,0.8);
#     top: 3px;
#     right: 3px;
#     width: 225px;
#     max-height: 600px;
#     overflow-x: hidden;
#     overflow-y: auto;
#     border: 1px solid #000;
#     padding: 0px;
# }
#
# div.jLMx3Dstandalone {
#     height: 100vh;
#     width: 100vw;
#     overflow: hidden;
# }
#
# div.jLMx3Dkeymin {
#     width: auto;
#     height: auto;
#     display: none;
#     border: 0px;
#     overflow: hidden;
# }
#
# div.jLMx3Dkeyhelp {
#     display: none;
#     position: absolute;
#     background-color: rgba(255,255,255,0.8);
#     bottom: 2px;
#     right: 300px;
#     width: 400px;
#     max-height: 600px;
#     overflow-x: hidden;
#     overflow-y: auto;
#     border: 1px solid #000;
#     padding: 10px;
# }
#
# div.jLMx3Dkeyhelpstandalone {
#     display: none;
#     position: absolute;
#     background-color: rgba(255,255,255,0.8);
#     top: 10px;
#     left: 10px;
#     width: 400px;
#     max-height: 95%;
#     overflow-x: hidden;
#     overflow-y: auto;
#     border: 1px solid #000;
#     padding: 10px;
# }
#
# button.jLMx3Dkey {
#     float: left;
#     margin: 0px;
#     -webkit-transition-duration: 0.4s;
#     transition-duration: 0.4s;
#     background-color: #def1f0;
#     padding: 10px 5px;
#     border: 1px solid #fff;
#     width: 33%;
# }
#
# button.jLMx3Dkey:hover {
#     background-color: #108e88;
#     color: #fff;
# }
#
# button.jLMx3dbtstandalone {
#     display: table-cell;
#     width: 50%;
# }
# button.jLMx3dbt {
#     display: table-cell;
# }
#
# div.jLMx3dbt {
#     display: table;
#     width: 225px;
# }
#
#
# ul.reg {
#     list-style-type: none;
#     width: 100%;
# }
#
# img.smallreg {
#     border:1px solid #000;
#     float: left;
#     image-rendering: -moz-crisp-edges;
#     image-rendering: -o-crisp-edges;
#     image-rendering: -webkit-optimize-contrast;
#     -ms-interpolation-mode: nearest-neighbor;
#     image-rendering: pixelated;
# }
#
# X3D.jLM {
#     width: 100%;
#     height: 90%;
#     border: 0px;
# }
#
# span.jLMparticleKey {
#     position: relative;
#     top: 3px;
#     font-size: 1.5em;
# }
#
# div.jLMbigSps {
#     font-family: serif;
#     background: #fff;
#     color: #000;
#     display: table-cell;
#     vertical-align: middle;
#     text-align: center;
#     height: 70px;
#     font-size: 3.2em;
#     padding: 40px 10px 10px 10px;
#     border: 0px;
# }
#
# input[type=range][orient=vertical].stackSlider {
#     writing-mode: bt-lr; /* IE */
#     display: block;
#     margin: auto;
#     -webkit-appearance: slider-vertical; /* WebKit */
#     width: 8px;
#     height: 250px;
#     padding: 15px;
# }
#
# span.jLMregion {
#     padding: 1px 4px;
#     margin: 2px;
#     display: inline-block;
#     font-family: sans-serif;
#     border: 1px solid black;
# }
#
# span.jLMnum, td.jLMnum {
#     font-family: serif;
#     font-size: 1.2em;
# }
#
# div.jLMdescription {
#     margin: 1em 3em;
#     font-style: italic;
# }</style>
# <script type="text/javascript">
#  var fontawesome_css = document.getElementById("fontawesome-css");
#  if (fontawesome_css === null) {
#     var l = document.createElement("link");
#     l.setAttribute("rel", "stylesheet");
#     l.setAttribute("type", "text/css");
#     l.setAttribute("href", "https://netdna.bootstrapcdn.com/font-awesome/3.2.1/css/font-awesome.css");
#     l.setAttribute("id", "fontawesome-css");
#     $("head").append(l);
# }
# </script>

# %% [markdown]
# ## 2.1 Initialization and spatial geometry

# %% [markdown]
# The workflow is the same as the Tutorial 1, we need to create a RDME simulation object `jLM.RDME.Sim` and define spatial geometry, species with relevant counts, diffusion coefficients and reactions.

# %%
cellvol = 1.0e-15                # L=dm^3
simname = "Lac Genetic Switch"
filename = "T2_lac2state.lm "

lattice_spacing = 32e-9            # in m

regionN = "extracellular"
dt = 50e-6                         # in s
# we need to create the LM region with (1.024,1.024,2.048) micron, 
# that can fully contain the E.coli
xdim = int(unitsconv.micron(1.024)/lattice_spacing)
ydim = int(unitsconv.micron(1.024)/lattice_spacing)
zdim = int(unitsconv.micron(2.048)/lattice_spacing)
Ldim = [xdim, ydim, zdim]                   # Has to be multiples of 32

print("dimension of the LM lattice: ", Ldim)
# Out:
# dimension of the LM lattice:  [32, 32, 64]

# %%
sim = RDMESim(  simname, 
                filename, 
                Ldim, 
                lattice_spacing, 
                regionN,
                dt)

# %% [markdown]
# Now we create a ellipsoid to represent the E.coli.

# %%
build = RegionBuilder(sim)
# cytoplasm = build.capsule(length=unitsconv.micron(1.8), width=unitsconv.micron(0.5))
capsule_l = int(unitsconv.micron(1.8)/lattice_spacing)
capsule_w = int(unitsconv.micron(0.5)/lattice_spacing)
print("capsule length: ", capsule_l, "\n capsule width: ", capsule_w)
cytoplasm = build.capsule(length=capsule_l, width=capsule_w)
# Out:
# capsule length:  56
#  capsule width:  15

# %% [markdown]
# Now we create the cell membrane for E.coli, which is 64nm.
#
# Consider the lattice_spacing = 32nm, we need 2 cube thick for the membrane.

# %%
cyto_dialiation = build.dilate(cytoplasm, radius=int(64/32))
membrane = cyto_dialiation &~ cytoplasm# cyto_di

# %% [markdown]
# make extracellualr exlude those regions.

# %%
extracellular = ~ (cytoplasm| membrane)

# %% [markdown]
# combine all regions into site lattice

# %%
cyt = sim.region('cytoplasm')
mem = sim.region('membrane')
ext = sim.region('extracellular')

build.compose(
    (sim.region('extracellular'), extracellular),
    (sim.region('cytoplasm'), cytoplasm),
    (sim.region('membrane'), membrane)
    )

# %%
sim.displayGeometry()
# Out:
# <div class="fullWidth" id="jLM_774GK75D">
# <X3D class="jLM" profile='Interchange' version='3.1' id='jLM_774GK75DX3D'>
#     <Scene>
#         <Environment SSAO="true" id='jLM_774GK75Denv' occlusionCulling='false'></Environment>
#         <background skyColor="1.0 1.0 1.0"></background>
#         <Transform rotation='0 1 0 1.57'>
#             <Transform scale='0.109375 0.109375 0.109375'>
#                 <Transform translation='-16.0 -16.0 -32.0'>
#
#                     <Shape id='jLM_774GK75Dshape0'>
#                        <Appearance>
#                            <Material id='jLM_774GK75Dmaterial0' transparency='0' diffuseColor='1.0 1.0 1.0'></Material>
#                            <DepthMode id='jLM_774GK75Ddm0' readOnly="false"></DepthMode>
#                        </Appearance>
#                        <IndexedTriangleSet solid='false' index='0 1 2 0 3 1 4 5 6 4 6 7 8 9 10 8 10 11 12 13 14 12 14 15 16 17 18 16 18 19 20 21 22 20 22 23 24 25 26 24 26 27 28 29 30 28 30 31 32 33 34 32 34 35 36 37 38 36 38 39 40 41 42 40 42 43 44 45 46 44 46 47 48 49 50 48 50 51 52 53 54 52 54 55 56 57 58 56 58 59 60 61 62 60 62 63 64 65 66 64 66 67 68 69 70 68 70 71 72 73 74 72 74 75 69 76 77 69 77 78 79 80 81 79 81 74 82 83 84 82 84 85 86 87 88 86 88 89 90 91 92 90 92 93 94 95 96 94 96 97 98 99 100 98 100 101 102 103 104 102 104 105 106 107 108 106 108 109 110 111 112 110 112 113 114 108 111 114 111 115 116 117 118 116 118 119 120 121 122 120 122 117 118 123 124 118 124 125 126 127 128 126 128 121 124 129 130 124 130 131 132 133 134 132 134 127 130 135 136 130 136 137 138 139 140 138 140 133 136 141 142 136 142 143 140 144 145 140 145 146 147 148 149 147 149 141 145 150 151 145 151 152 153 154 155 153 155 148 151 156 157 151 157 158 159 160 161 159 161 154 157 162 163 157 163 160 164 165 166 164 166 167 168 169 170 168 170 165 166 171 172 166 172 173 174 175 176 174 176 169 172 177 178 172 178 179 180 181 182 180 182 175 178 183 184 178 184 185 186 187 188 186 188 181 184 189 190 184 190 191 192 193 194 192 194 187 190 195 196 190 196 197 194 198 199 194 199 200 201 202 203 201 203 195 199 204 205 199 205 206 207 208 209 207 209 202 205 210 211 205 211 212 213 214 215 213 215 208 211 216 217 211 217 218 219 220 221 219 221 214 217 222 223 217 223 220 224 225 226 224 226 227 228 229 230 228 230 231 232 233 234 232 234 235 236 237 238 236 238 229 234 239 240 234 240 241 242 243 244 242 244 237 240 245 246 240 246 247 248 249 250 248 250 243 246 251 252 246 252 253 254 255 256 254 256 249 252 257 258 252 258 259 260 261 262 260 262 263 264 265 266 264 266 267 262 268 269 262 269 270 271 272 273 271 273 265 269 274 275 269 275 276 277 278 279 277 279 272 275 280 281 275 281 282 283 284 285 283 285 278 281 286 287 281 287 288 289 290 291 289 291 284 292 293 294 292 294 295 296 297 298 296 298 299 300 301 302 300 302 303 304 305 306 304 306 307 308 309 310 308 310 311 312 313 314 312 314 305 310 315 316 310 316 317 318 319 320 318 320 313 316 321 322 316 322 323 324 325 326 324 326 319 322 327 328 322 328 329 330 331 332 330 332 333 334 335 336 334 336 337 338 339 340 338 340 341 342 343 344 342 344 345 340 346 347 340 347 348 349 350 351 349 351 343 347 352 353 347 353 354 355 356 357 355 357 350 353 358 359 353 359 360 361 362 363 361 363 356 364 365 366 364 366 367 368 369 370 368 370 371 372 373 374 372 374 375 376 377 378 376 378 379 380 381 382 380 382 383 384 385 386 384 386 387 388 389 390 388 390 391 392 393 394 392 394 395 396 397 398 396 398 399 400 401 402 400 402 403 404 405 406 404 406 407 408 409 410 408 410 411 412 413 414 412 414 415 416 417 418 416 418 419 420 421 422 420 422 423 424 425 426 424 426 427 428 429 430 428 430 421 426 431 432 426 432 433 434 435 436 434 436 429 432 437 438 432 438 439 440 441 442 440 442 443 444 445 446 444 446 447 442 448 449 442 449 450 451 452 453 451 453 445 449 454 455 449 455 456 457 458 459 457 459 452 460 461 462 460 462 463 464 465 466 464 466 467 468 469 470 468 470 471 472 473 474 472 474 475 476 477 478 476 478 479 480 481 482 480 482 483 484 485 486 484 486 487 488 489 490 488 490 491 492 493 494 492 495 493 496 497 498 496 499 497 500 501 502 500 503 501 504 505 506 504 507 505 508 509 510 508 511 509 512 513 514 512 515 513 516 517 518 516 519 517 520 521 522 520 523 521 524 525 526 524 527 525 528 529 530 528 531 529 532 533 534 532 526 533 529 535 536 529 537 535 538 539 540 538 534 539 535 541 542 535 543 541 544 545 546 544 547 545 548 549 550 548 551 549 545 552 553 545 554 552 555 556 557 555 550 556 552 558 559 552 560 558 561 562 563 561 557 562 564 565 566 564 567 565 568 569 570 568 571 569 572 573 574 572 575 573 576 577 578 576 579 577 580 581 582 580 583 581 584 585 586 584 587 585 588 589 590 588 591 589 592 593 594 592 595 593 596 597 598 596 599 597  ...

# %% [markdown]
# ## 2.2 Initialization of Species

# %% [markdown]
# Lactose Gene, Product and Inducer Species
# + O - *lac* operator (e.g. the *lac* gene); it is transcribed to produce mY
# + mY - mRNA that encodes the lactose permease; it is translated to produce Y
# + Y - lactose permease; it can transport inducer into the cell
# + I - intracellular inducer (lactose analog)
# + Iex - extracellular inducer
# + YI - lactose analog bound by the lactose permease
#
# Free (cytosolic) Repressor Sepcies
# + R2 - free repressor dimer
# + IR2 - free repressor with a single inducer bound
# + I2R2 - free repressor with inducer bound to both dimer subunits
#
# Repressed Gene Species
# + R2O - repressed gene with dimer sitting on the operator
# + IR2O - repressed gene with a single inducer bound to the dimer
# + I2R2O - repressed gene with inducer molecules bound to both dimer subunits

# %%
species_all = ['R2','O','R2O','IR2','IR2O','I2R2','I2R2O','mY','Y','I','Iex','YI']
with sim.construct():
    for sp in species_all:
        sim.species(sp)
# Out:
# <table class='jLMtbl'>
#     <caption>New Species</caption>
#     <tr>
#         <th>Index</th>
#         <th>Name</th>
#     </tr>
#     <tr>
#         <td> 1 </td>
#         <td> <span class='jLMnum'>R2</span> </td>
#     </tr>
#     <tr>
#         <td> 2 </td>
#         <td> <span class='jLMnum'>O</span> </td>
#     </tr>
#     <tr>
#         <td> 3 </td>
#         <td> <span class='jLMnum'>R2O</span> </td>
#     </tr>
#     <tr>
#         <td> 4 </td>
#         <td> <span class='jLMnum'>IR2</span> </td>
#     </tr>
#     <tr>
#         <td> 5 </td>
#         <td> <span class='jLMnum'>IR2O</span> </td>
#     </tr>
#     <tr>
#         <td> 6 </td>
#         <td> <span class='jLMnum'>I2R2</span> </td>
#     </tr>
#     <tr>
#         <td> 7 </td>
#         <td> <span class='jLMnum'>I2R2O</span> </td>
#     </tr>
#     <tr>
#         <td> 8 </td>
#         <td> <span class='jLMnum'>mY</span> </td>
#     </tr>
#     <tr>
#         <td> 9 </td>
#         <td> <span class='jLMnum'>Y</span> </td>
#     </tr>
#     <tr>
#         <td> 10 </td>
#         <td> <span class='jLMnum'>I</span> </td>
#     </tr>
#     <tr>
#         <td> 11 </td>
#         <td> <span class='jLMnum'>Iex</span> </td>
#     </tr>
#     <tr>
#         <td> 12 </td>
#         <td> <span class='jLMnum'>YI</span> </td>
#     </tr>
# </table>

# %% [markdown]
# ## 2.3 Initialization of reactions

# %%
scalar = 2.076e-9 # Rate conversion from experiments to stochastic
sp = sim.sp
rc = sim.rc

# %% [markdown]
# ### 2.3.1 Lac operon regulation

# %%
with sim.construct():
    #sim.rateConst(rate, value, order [, texRepr, annotation])
    sim.rateConst('k1', 2.43e6*scalar,2)
    sim.rateConst('k2', 1.21e6*scalar,2)
    sim.rateConst('k3', 2.43e4*scalar,2)
    sim.rateConst('k4', 6.30e-4     ,1)
    sim.rateConst('k5', 6.30e-4     ,1)
    sim.rateConst('k6', 3.15e-1     ,1)
    
    # region.addReaction(reactants, products, rate)
    cyt.addReaction([sp.R2,sp.O]    ,[sp.R2O]       ,rc.k1)
    cyt.addReaction([sp.IR2,sp.O]   ,[sp.IR2O]      ,rc.k2)
    cyt.addReaction([sp.I2R2,sp.O]  ,[sp.I2R2O]     ,rc.k3)
    cyt.addReaction([sp.R2O]        ,[sp.R2,sp.O]   ,rc.k4)
    cyt.addReaction([sp.IR2O]       ,[sp.IR2,sp.O] ,rc.k5)
    cyt.addReaction([sp.I2R2O]      ,[sp.I2R2,sp.O] ,rc.k6)
# Out:
# <table class='jLMtbl'>
#     <caption>New reactions</caption>
#     <tr>
#         <th>Index</th>
#         <th>Reaction</th>
#         <th>Rate</th>
#         <th>Regions</th>
#     </tr>
#     <tr>
#         <td> 1 </td>
#         <td class="rxnCol"> $$\mathrm{IR2} + \mathrm{O}\overset{k_{\mathrm{k2}}}{\longrightarrow}\mathrm{IR2O}$$ </td>
#         <td class='jLMnum noWrap'> 2.512 × 10<sup>-3</sup> M<sup>-1</sup>⋅s<sup>-1</sup>&nbsp; </td>
#         <td class='noWrap'> <span class="jLMregion" style="color:#000000;background:#51cccc;">cytoplasm</span> </td>
#     </tr>
#     <tr>
#         <td> 2 </td>
#         <td class="rxnCol"> $$\mathrm{I2R2} + \mathrm{O}\overset{k_{\mathrm{k3}}}{\longrightarrow}\mathrm{I2R2O}$$ </td>
#         <td class='jLMnum noWrap'> 5.045 × 10<sup>-5</sup> M<sup>-1</sup>⋅s<sup>-1</sup>&nbsp; </td>
#         <td class='noWrap'> <span class="jLMregion" style="color:#000000;background:#51cccc;">cytoplasm</span> </td>
#     </tr>
#     <tr>
#         <td> 3 </td>
#         <td class="rxnCol"> $$\mathrm{R2O}\overset{k_{\mathrm{k4}}}{\longrightarrow}\mathrm{R2} + \mathrm{O}$$ </td>
#         <td class='jLMnum noWrap'> 6.300 × 10<sup>-4</sup> s<sup>-1</sup>&nbsp; </td>
#         <td class='noWrap'> <span class="jLMregion" style="color:#000000;background:#51cccc;">cytoplasm</span> </td>
#     </tr>
#     <tr>
#         <td> 4 </td>
#         <td class="rxnCol"> $$\mathrm{IR2O}\overset{k_{\mathrm{k5}}}{\longrightarrow}\mathrm{IR2} + \mathrm{O}$$ </td>
#         <td class='jLMnum noWrap'> 6.300 × 10<sup>-4</sup> s<sup>-1</sup>&nbsp; </td>
#         <td class='noWrap'> <span class="jLMregion" style="color:#000000;background:#51cccc;">cytoplasm</span> </td>
#     </tr>
#     <tr>
#         <td> 5 </td>
#         <td class="rxnCol"> $$\mathrm{I2R2O}\overset{k_{\mathrm{k6}}}{\longrightarrow}\mathrm{I2R2} + \mathrm{O}$$ </td>
#         <td class='jLMnum noWrap'> 0.315 s<sup>-1</sup>&nbsp; </td>
#         <td class='noWrap'> <span class="jLMregion" style="color:#000000;background:#51cccc;">cytoplasm</span> </td>
#     </tr>
# </table>

# %% [markdown]
# ### 2.3.2 Genetic Information process
# Transcription, translation, and degredation

# %%
with sim.construct():
    sim.rateConst('k7', 1.26e-1,1)
    sim.rateConst('k8', 4.44e-2,1)
    sim.rateConst('k9', 1.11e-2,1)
    sim.rateConst('k10', 2.10e-4,1)
    
    cyt.addReaction([sp.O]         ,[sp.O, sp.mY]   ,sc.k7)
    mem.addReaction([sp.mY]        ,[sp.mY, sp.Y]   ,sc.k8)
    cyt.addReaction('mY',         '',           1.11e-2)
    mem.addReaction('mY',         '',           1.11e-2)
    mem.addReaction('Y',          '',           2.10e-4)

# %% [markdown]
# ### 2.3.3 Inducer-repressor interactions

# %%
cyt.addReaction(('I','R2'),   'IR2',        2.27e4*scalar)
cyt.addReaction(('I','IR2'),  'I2R2',       1.14e4*scalar)
cyt.addReaction(('I','R2O'),  'IR2O',       6.67e2*scalar)
cyt.addReaction(('I','IR2O'), 'I2R2O',      3.33e2*scalar)
cyt.addReaction('IR2',        ('I','R2'),   2.00e-1)
cyt.addReaction('I2R2',       ('I','IR2'),  4.00e-1)
cyt.addReaction('IR2O',       ('I','R2O'),  1.00)
cyt.addReaction('I2R2O',      ('I','IR2O'), 2.00)

# %% [markdown]
# ### 2.3.4 Inducer Transport

# %%
mem.addReaction('Iex',        'I',          2.33e-3)
mem.addReaction('I',          'Iex',        2.33e-3)
mem.addReaction(('Y','Iex'),  'YI',         3.03e4*scalar)
mem.addReaction('YI',         ('Y','Iex'),  1.20e-1)
mem.addReaction('YI',         ('Y','I'),    1.20e+1)
